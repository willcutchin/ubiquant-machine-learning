# %%
# Import libraries
import pandas as pd
import numpy as np
import csv

# %%
# Load the original "Training Data Set"
full_path = "~/Desktop/School/C365_data_analytics_and_mining/final_project/ubiquant-machine-learning/data/training_data/original_training_set/train.csv"

df = pd.read_csv(full_path)

# %%
# Check Load
df.head()
# Out:
#   row_id  time_id  investment_id    target       f_0       f_1       f_2  \
# 0    0_1        0              1 -0.300875  0.932573  0.113691 -0.402206
# 1    0_2        0              2 -0.231040  0.810802 -0.514115  0.742368
# 2    0_6        0              6  0.568807  0.393974  0.615937  0.567806
# 3    0_7        0              7 -1.064780 -2.343535 -0.011870  1.874606
# 4    0_8        0              8 -0.531940  0.842057 -0.262993  2.330030
#
#         f_3       f_4       f_5  ...     f_290     f_291     f_292     f_293  \
# 0  0.378386 -0.203938 -0.413469  ...  0.366028 -1.095620  0.200075  0.819155
# 1 -0.616673 -0.194255  1.771210  ... -0.154193  0.912726 -0.734579  0.819155
# 2 -0.607963  0.068883 -1.083155  ... -0.138020  0.912726 -0.551904 -1.220772
# 3 -0.606346 -0.586827 -0.815737  ...  0.382201  0.912726 -0.266359 -1.220772
# 4 -0.583422 -0.618392 -0.742814  ... -0.170365  0.912726 -0.741355 -1.220772
#
#       f_294     f_295     f_296     f_297     f_298     f_299
# ...

# %%
# Creating 15 Random Sample Files
sample_count = 15
sample_size = 50000
counter = 0
for i in range(0, sample_count):
    sample = df.sample(n=sample_size)
    counter += 1
    sample.to_csv(r'~/Desktop/School/C365_data_analytics_and_mining/final_project/ubiquant-machine-learning/data/training_data/random_sample_set/samples/random_training_sample_' + str(counter) +".csv")
    print("sample" + str(counter) + "saved")
# Out:
# sample1saved
# sample2saved
# sample3saved
# sample4saved
# sample5saved
# sample6saved
# sample7saved
# sample8saved
# sample9saved
# sample10saved
# sample11saved
# sample12saved
# sample13saved
# sample14saved
# sample15saved

# %%
description_path = "~/Desktop/School/C365_data_analytics_and_mining/final_project/ubiquant-machine-learning/data/training_data/random_sample_set/descriptions/"

# %%
# Take the description of the Training file and save it to csv
df.describe().to_csv(description_path + "train_data_description.csv")

# %%
# Take the description of each Sample and save it as a csv
sample_path = "~/Desktop/School/C365_data_analytics_and_mining/final_project/ubiquant-machine-learning/data/training_data/random_sample_set/samples/"
sample_count = 15
counter = 0
for i in range(0, sample_count):
    counter += 1
    sample = pd.read_csv(sample_path + "random_training_sample_" + str(counter) +".csv")
    sample.describe().to_csv(description_path + "random_training_sample_description_" + str(counter) + ".csv")
    print("sample description saved: " + str(counter))
# Out:
# sample description saved: 1
# sample description saved: 2
# sample description saved: 3
# sample description saved: 4
# sample description saved: 5
# sample description saved: 6
# sample description saved: 7
# sample description saved: 8
# sample description saved: 9
# sample description saved: 10
# sample description saved: 11
# sample description saved: 12
# sample description saved: 13
# sample description saved: 14
# sample description saved: 15
